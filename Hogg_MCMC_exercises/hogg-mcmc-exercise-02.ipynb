# %%
# %pylab inline
# %config InlineBackend.figure_format = 'retina'
import scipy.stats as stats
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Initialize the x- and y-arrays that we will use to plot
x_axis = []
mean = []
variance = []
skew_list = []
kurt_list = []

# generate gaussian pdf of x
mu = 2.0
variance = 2.0
sigma = math.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
#plot(x, stats.norm.pdf(x, mu, sigma))
#show()

# %%
# proposal
def q(x):
    # add a random number drawn from a gaussian whose mean is the current position and the standard deviation is 1
    # randn() draws from a normalized gausian whose mean is 0 and stdev is 1
    return x + randn()

# %%
# density function f(x)
def f(x):
    mu = 0
    sigma = math.sqrt(2)
    return 1.0/(sigma*math.sqrt(2.0*pi)) * exp(-0.5 * ((x-mu)/sigma)**2)

# %%
xs = [0]    # initialize MCMC algorithm with arbitrary starting value of x
for i in range(10000):
    x = xs[-1]
    x_new = q(x)
    accept_ratio = f(x_new)/f(x)
    if rand() < accept_ratio:
        xs.append(x_new)
    else:
        xs.append(x)

# %%
plot(xs)

# %%
hist(xs, density=True, bins=20)
# Out:
# (array([0.00228492, 0.00498527, 0.01246317, 0.0286653 , 0.04798322,
#         0.08516502, 0.1379258 , 0.21062765, 0.25632595, 0.27689019,
#         0.27356668, 0.23638487, 0.19442552, 0.13231737, 0.08516502,
#         0.05255305, 0.02492635, 0.00976282, 0.00394667, 0.0010386 ]),
#  array([-2.83018427, -2.34881413, -1.86744398, -1.38607383, -0.90470368,
#         -0.42333354,  0.05803661,  0.53940676,  1.0207769 ,  1.50214705,
#          1.9835172 ,  2.46488735,  2.94625749,  3.42762764,  3.90899779,
#          4.39036794,  4.87173808,  5.35310823,  5.83447838,  6.31584852,
#          6.79721867]),
#  <a list of 20 Patch objects>)
