# %%
# %pylab inline
# %config InlineBackend.figure_format = 'retina'
import scipy.stats as stats
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Initialize the x- and y-arrays that we will use to plot
x_axis = []
mean = []
variance = []
skew_list = []
kurt_list = []

# generate gaussian pdf of x
mu = 2.0
variance = 2.0
sigma = math.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
#plot(x, stats.norm.pdf(x, mu, sigma))
#show()

# %%
# proposal
def q(x):
    # add a random number drawn from a gaussian whose mean is the current position and the standard deviation is 1
    # randn() draws from a normalized gausian whose mean is 0 and stdev is 1
    return x + randn()

# %%
# density function f(x)
def f(x):
    mu = 2
    sigma = math.sqrt(2)
    return 1.0/(sigma*math.sqrt(2.0*pi)) * exp(-0.5 * ((x-mu)/sigma)**2)

# %%
xs = [3]    # initialize MCMC algorithm with arbitrary starting value of x
for i in range(10000):
    x = xs[-1]
    x_new = q(x)
    accept_ratio = f(x_new)/f(x)
    if rand() < accept_ratio:
        xs.append(x_new)
    else:
        xs.append(x)

# %%
plot(xs)

# %%
hist(xs, normed=True, bins=20)
# Out:
# c:\software\python\python3.7.4\lib\site-packages\ipykernel_launcher.py:1: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   """Entry point for launching an IPython kernel.
# (array([2.01934090e-04, 4.03868181e-04, 5.45222044e-03, 1.25199136e-02,
#         2.62514318e-02, 5.31086658e-02, 1.09650211e-01, 1.49027359e-01,
#         2.07790179e-01, 2.57264031e-01, 2.65745263e-01, 2.56658229e-01,
#         2.34243545e-01, 1.78307802e-01, 1.19141113e-01, 7.41098112e-02,
#         3.93771476e-02, 2.18088818e-02, 6.86575907e-03, 1.61547272e-03]),
#  array([-3.23060015, -2.73543858, -2.24027702, -1.74511545, -1.24995388,
#         -0.75479231, -0.25963074,  0.23553083,  0.7306924 ,  1.22585397,
#          1.72101553,  2.2161771 ,  2.71133867,  3.20650024,  3.70166181,
#          4.19682338,  4.69198495,  5.18714652,  5.68230809,  6.17746965,
#          6.67263122]),
#  <a list of 20 Patch objects>)
